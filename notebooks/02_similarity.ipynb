# %%
import sys, os
sys.path.append(os.path.abspath("../"))
import pandas as pd
from src.similarity_engine import SimilarityEngine

df = pd.read_csv("../data/processed/clean_cases.csv")

engine = SimilarityEngine(df)

case = df["dr_no"].iloc[0]
engine.get_similar_cases(case, top_k=5)
# Out:
#              dr_no    datetime    area_name  crm_cd        crm_cd_desc  \
# 1004872  241510681  2024-04-19  N Hollywood     354  THEFT OF IDENTITY
# 378669   211511126  2021-06-22  N Hollywood     354  THEFT OF IDENTITY
# 45       220614831  2020-08-17    Hollywood     354  THEFT OF IDENTITY
# 248313   220619862  2021-07-20    Hollywood     354  THEFT OF IDENTITY
# 14847    201506137  2020-02-07  N Hollywood     354  THEFT OF IDENTITY
#
#         weapon_desc  vict_age vict_sex                            mo_text  \
# 1004872         NaN        37        M  theft of identity nan n hollywood
# 378669          NaN        63        M  theft of identity nan n hollywood
# 45              NaN        28        M    theft of identity nan hollywood
# 248313          NaN        43        M    theft of identity nan hollywood
# 14847           NaN        32        F  theft of identity nan n hollywood
#
#          similarity
# 1004872         1.0
# 378669          1.0
# 45              1.0
# 248313          1.0
# 14847           1.0

# %%
engine.get_similar_cases(case, top_k=10)
# Out:
#              dr_no    datetime    area_name  crm_cd        crm_cd_desc  \
# 1004872  241510681  2024-04-19  N Hollywood     354  THEFT OF IDENTITY
# 378669   211511126  2021-06-22  N Hollywood     354  THEFT OF IDENTITY
# 45       220614831  2020-08-17    Hollywood     354  THEFT OF IDENTITY
# 248313   220619862  2021-07-20    Hollywood     354  THEFT OF IDENTITY
# 14847    201506137  2020-02-07  N Hollywood     354  THEFT OF IDENTITY
# 14901    211504732  2020-11-16  N Hollywood     354  THEFT OF IDENTITY
# 14891    240605854  2020-12-20    Hollywood     354  THEFT OF IDENTITY
# 587896   221508536  2022-04-10  N Hollywood     354  THEFT OF IDENTITY
# 930358   240606096  2024-02-01    Hollywood     354  THEFT OF IDENTITY
# 681519   230614877  2023-09-02    Hollywood     354  THEFT OF IDENTITY
#
#         weapon_desc  vict_age vict_sex                            mo_text  \
# 1004872         NaN        37        M  theft of identity nan n hollywood
# 378669          NaN        63        M  theft of identity nan n hollywood
# 45              NaN        28        M    theft of identity nan hollywood
# 248313          NaN        43        M    theft of identity nan hollywood
# 14847           NaN        32        F  theft of identity nan n hollywood
# 14901           NaN        51        M  theft of identity nan n hollywood
# 14891           NaN        26        F    theft of identity nan hollywood
# 587896          NaN        19        M  theft of identity nan n hollywood
# 930358          NaN        44        M    theft of identity nan hollywood
# 681519          NaN        40        F    theft of identity nan hollywood
#
#          similarity
# 1004872         1.0
# 378669          1.0
# 45              1.0
# 248313          1.0
# 14847           1.0
# 14901           1.0
# 14891           1.0
# 587896          1.0
# 930358          1.0
# 681519          1.0
