# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/clean_cases.csv")
df["datetime"] = pd.to_datetime(df["datetime"])

df.resample("M", on="datetime").size().plot()
plt.title("Crime Count per Month")
plt.show()
# Out:
# C:\Users\prasanth\AppData\Local\Temp\ipykernel_1544\648091697.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample("M", on="datetime").size().plot()
